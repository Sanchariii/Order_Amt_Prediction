# %% [markdown]
# # Pandas Fundamentals Part - 2

# %% [markdown]
# ## Understanding Dataset

# %%
import pandas as pd
df = pd.read_csv("weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (145557, 23)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  144072.000000  144296.000000  142295.000000  82670.000000
# mean       12.196225      23.226846       2.359786      5.468232
# std         6.397911       7.121473       8.475588      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135291.000000  143789.000000  142494.000000
# mean       7.611178      40.036994      14.041797      18.662028
# std        3.785483      13.607081       8.914488       8.809539
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  142903.000000  141050.000000  130492.000000  130529.000000
# mean       68.866994      51.520588    1017.645698    1015.251247
# std        19.032542      20.804909       7.106752       7.037922
# min         0.000000       0.000000     980.500000     977.100000
# 25%        57.000000      37.000000    1012.900000    1010.400000
# 50%        70.000000      52.000000    1017.600000    1015.200000
# 75%        83.000000      66.000000    1022.400000    1020.000000
# max       100.000000     100.000000    1041.000000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am        Temp3pm
# count  89589.000000  86121.000000  143790.000000  141948.000000
# mean       4.447655      4.509922      16.993324      21.688880
# std        2.887171      2.720464       6.488477       6.939335
# min        0.000000      0.000000      -7.200000      -5.400000
# 25%        1.000000      2.000000      12.300000      16.600000
# 50%        5.000000      5.000000      16.700000      21.100000
# 75%        7.000000      7.000000      21.600000      26.400000
# max        9.000000      9.000000      40.200000      46.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145557 entries, 0 to 145556
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145557 non-null  object
#  1   Location       145557 non-null  object
#  2   MinTemp        144072 non-null  float64
#  3   MaxTemp        144296 non-null  float64
#  4   Rainfall       142295 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135228 non-null  object
#  8   WindGustSpeed  135291 non-null  float64
#  9   WindDir9am     134985 non-null  object
#  10  WindDir3pm     141325 non-null  object
#  11  WindSpeed9am   143789 non-null  float64
#  12  WindSpeed3pm   142494 non-null  float64
#  13  Humidity9am    142903 non-null  float64
#  14  Humidity3pm    141050 non-null  float64
#  15  Pressure9am    130492 non-null  float64
#  16  Pressure3pm    130529 non-null  float64
#  17  Cloud9am       89589 non-null   float64
#  18  Cloud3pm       86121 non-null   float64
#  19  Temp9am        143790 non-null  float64
#  20  Temp3pm        141948 non-null  float64
#  21  RainToday      142295 non-null  object
#  22  RainTomorrow   142289 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %% [markdown]
# # Data Dropping

# %%
df = pd.read_csv("weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %% [markdown]
# # Percentage of null value

# %%
df.isnull().mean()*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020219
# MaxTemp           0.866327
# Rainfall          2.241046
# Evaporation      43.204380
# Sunshine         48.044409
# WindGustDir       7.096189
# WindGustSpeed     7.052907
# WindDir9am        7.263134
# WindDir3pm        2.907452
# WindSpeed9am      1.214644
# WindSpeed3pm      2.104330
# Humidity9am       1.823341
# Humidity3pm       3.096381
# Pressure9am      10.349897
# Pressure3pm      10.324478
# Cloud9am         38.450916
# Cloud3pm         40.833488
# Temp9am           1.213957
# Temp3pm           2.479441
# RainToday         2.241046
# RainTomorrow      2.245169
# dtype: float64

# %%
(df.isnull().sum() /len(df))*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020219
# MaxTemp           0.866327
# Rainfall          2.241046
# Evaporation      43.204380
# Sunshine         48.044409
# WindGustDir       7.096189
# WindGustSpeed     7.052907
# WindDir9am        7.263134
# WindDir3pm        2.907452
# WindSpeed9am      1.214644
# WindSpeed3pm      2.104330
# Humidity9am       1.823341
# Humidity3pm       3.096381
# Pressure9am      10.349897
# Pressure3pm      10.324478
# Cloud9am         38.450916
# Cloud3pm         40.833488
# Temp9am           1.213957
# Temp3pm           2.479441
# RainToday         2.241046
# RainTomorrow      2.245169
# dtype: float64

# %%
df.shape
# Out:
# (145557, 23)

# %% [markdown]
# # Drop Duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# # Drop all NULL or NAN values

# %%
df.dropna()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    01-01-2009    Cobar     17.9     35.2       0.0         12.0
# 6050    02-01-2009    Cobar     18.4     28.9       0.0         14.8
# 6052    04-01-2009    Cobar     19.4     37.6       0.0         10.8
# 6053    05-01-2009    Cobar     21.9     38.4       0.0         11.4
# 6054    06-01-2009    Cobar     24.2     41.0       0.0         11.2
# ...            ...      ...      ...      ...       ...          ...
# 142298  20-06-2017   Darwin     19.3     33.4       0.0          6.0
# 142299  21-06-2017   Darwin     21.2     32.6       0.0          7.6
# 142300  22-06-2017   Darwin     20.7     32.8       0.0          5.6
# 142301  23-06-2017   Darwin     19.5     31.8       0.0          6.2
# 142302  24-06-2017   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 6049        12.3         SSW           48.0        ENE  ...        20.0
# 6050        13.0           S           37.0        SSE  ...        30.0
# 6052        10.6         NNE           46.0        NNE  ...        42.0
# 6053        12.2         WNW           31.0        WNW  ...        37.0
# 6054         8.4         WNW           35.0         NW  ...        19.0
# ...          ...         ...            ...        ...  ...         ...
# 142298      11.0         ENE           35.0         SE  ...        63.0
# 142299       8.6           E           37.0         SE  ...        56.0
# 142300      11.0           E           33.0          E  ...        46.0
# 142301      10.6         ESE           26.0         SE  ...        62.0
# 142302      10.7         ENE           30.0        ENE  ...        73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 6049           13.0       1006.3       1004.4       2.0       5.0     26.6
# 6050            8.0       1012.9       1012.1       1.0       1.0     20.3
# 6052           22.0       1012.3       1009.2       1.0       6.0     28.7
# 6053           22.0       1012.7       1009.1       1.0       5.0     29.1
# 6054           15.0       1010.7       1007.4       1.0       6.0     33.6
# ...             ...          ...          ...       ...       ...      ...
# 142298         32.0       1013.9       1010.5       0.0       1.0     24.5
# 142299         28.0       1014.6       1011.2       7.0       0.0     24.8
# 142300         23.0       1015.3       1011.8       0.0       0.0     24.8
# 142301         58.0       1014.9       1010.7       1.0       1.0     24.8
# 142302         32.0       1013.9       1009.7       6.0       5.0     25.4
#
#         Temp3pm  RainToday  RainTomorrow
# 6049       33.4         No            No
# 6050       27.0         No            No
# 6052       34.9         No            No
# 6053       35.6         No            No
# 6054       37.6         No            No
# ...         ...        ...           ...
# 142298     32.3         No            No
# 142299     32.0         No            No
# 142300     32.1         No            No
# 142301     29.2         No            No
# 142302     31.0         No            No
#
# [56420 rows x 23 columns]

# %% [markdown]
# # Fill all null values with 4

# %%
df.fillna(4)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       01-12-2008   Albury     13.4     22.9       0.6          4.0
# 1       02-12-2008   Albury      7.4     25.1       0.0          4.0
# 2       03-12-2008   Albury     12.9     25.7       0.0          4.0
# 3       04-12-2008   Albury      9.2     28.0       0.0          4.0
# 4       05-12-2008   Albury     17.5     32.3       1.0          4.0
# ...            ...      ...      ...      ...       ...          ...
# 145455  21-06-2017    Uluru      2.8     23.4       0.0          4.0
# 145456  22-06-2017    Uluru      3.6     25.3       0.0          4.0
# 145457  23-06-2017    Uluru      5.4     26.9       0.0          4.0
# 145458  24-06-2017    Uluru      7.8     27.0       0.0          4.0
# 145459  25-06-2017    Uluru     14.9      4.0       0.0          4.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            4.0           W           44.0          W  ...        71.0
# 1            4.0         WNW           44.0        NNW  ...        44.0
# 2            4.0         WSW           46.0          W  ...        38.0
# 3            4.0          NE           24.0         SE  ...        45.0
# 4            4.0           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       4.0           E           31.0         SE  ...        51.0
# 145456       4.0         NNW           22.0         SE  ...        56.0
# 145457       4.0           N           37.0         SE  ...        53.0
# 145458       4.0          SE           28.0        SSE  ...        51.0
# 145459       4.0           4            4.0        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       4.0     16.9
# 1              25.0       1010.6       1007.8       4.0       4.0     17.2
# 2              30.0       1007.6       1008.7       4.0       2.0     21.0
# 3              16.0       1017.6       1012.8       4.0       4.0     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       4.0       4.0     10.1
# 145456         21.0       1023.5       1019.1       4.0       4.0     10.9
# 145457         24.0       1021.0       1016.8       4.0       4.0     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No             4
#
# [145460 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # Dropping some columns

# %%
df.drop(columns=['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
       'Sunshine'])
# Out:
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0                W           44.0          W        WNW          20.0
# 1              WNW           44.0        NNW        WSW           4.0
# 2              WSW           46.0          W        WSW          19.0
# 3               NE           24.0         SE          E          11.0
# 4                W           41.0        ENE         NW           7.0
# ...            ...            ...        ...        ...           ...
# 145455           E           31.0         SE        ENE          13.0
# 145456         NNW           22.0         SE          N          13.0
# 145457           N           37.0         SE        WNW           9.0
# 145458          SE           28.0        SSE          N          13.0
# 145459         NaN            NaN        ESE        ESE          17.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               24.0         71.0         22.0       1007.7       1007.1
# 1               22.0         44.0         25.0       1010.6       1007.8
# 2               26.0         38.0         30.0       1007.6       1008.7
# 3                9.0         45.0         16.0       1017.6       1012.8
# 4               20.0         82.0         33.0       1010.8       1006.0
# ...              ...          ...          ...          ...          ...
# 145455          11.0         51.0         24.0       1024.6       1020.3
# 145456           9.0         56.0         21.0       1023.5       1019.1
# 145457           9.0         53.0         24.0       1021.0       1016.8
# 145458           7.0         51.0         24.0       1019.4       1016.5
# 145459          17.0         62.0         36.0       1020.2       1017.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0            8.0       NaN     16.9     21.8        No           No
# 1            NaN       NaN     17.2     24.3        No           No
# 2            NaN       2.0     21.0     23.2        No           No
# 3            NaN       NaN     18.1     26.5        No           No
# 4            7.0       8.0     17.8     29.7        No           No
# ...          ...       ...      ...      ...       ...          ...
# 145455       NaN       NaN     10.1     22.4        No           No
# 145456       NaN       NaN     10.9     24.5        No           No
# 145457       NaN       NaN     12.5     26.1        No           No
# 145458       3.0       2.0     15.1     26.0        No           No
# 145459       8.0       8.0     15.0     20.9        No          NaN
#
# [145460 rows x 16 columns]

# %%
df.WindGustDir.value_counts()
# Out:
# W      9915
# SE     9418
# N      9313
# SSE    9216
# E      9181
# S      9168
# WSW    9069
# SW     8967
# SSW    8736
# WNW    8252
# NW     8122
# ENE    8104
# ESE    7372
# NE     7133
# NNW    6620
# NNE    6548
# Name: WindGustDir, dtype: int64

# %% [markdown]
# # groupby

# %%
df.groupby("WindGustDir")['Temp3pm'].mean()
# Out:
# WindGustDir
# E      24.905872
# ENE    24.972399
# ESE    23.908872
# N      21.491516
# NE     24.390088
# NNE    23.270722
# NNW    20.760471
# NW     20.769462
# S      20.587231
# SE     23.186873
# SSE    21.726162
# SSW    20.391357
# SW     20.017032
# W      19.155222
# WNW    20.285444
# WSW    19.443849
# Name: Temp3pm, dtype: float64

# %% [markdown]
# # merge()

# %%
Marks = pd.DataFrame({'name' : ['Walter','White','Saul','Goodman'],
    'marks' : [70,75,80,90]})
Age = pd.DataFrame({'name' : ['Walter','Saul','Goodman','Hank'],
    'age' : [21,22,20,24],
      'Hobby' : ['Cooking', 'Reading', 'Playing','Collecting Minerals']})

# %%
Marks
# Out:
#       name  marks
# 0   Walter     70
# 1    White     75
# 2     Saul     80
# 3  Goodman     90

# %%
Age
# Out:
#       name  age                Hobby
# 0   Walter   21              Cooking
# 1     Saul   22              Reading
# 2  Goodman   20              Playing
# 3     Hank   24  Collecting Minerals

# %%
Left_Join = pd.merge(Marks, Age, on = 'name', how = 'left')
Left_Join
# Out:
#       name  marks   age    Hobby
# 0   Walter     70  21.0  Cooking
# 1    White     75   NaN      NaN
# 2     Saul     80  22.0  Reading
# 3  Goodman     90  20.0  Playing

# %%
Right_Join = pd.merge(Marks,Age, on = 'name', how = 'right')
Right_Join
# Out:
#       name  marks  age                Hobby
# 0   Walter   70.0   21              Cooking
# 1     Saul   80.0   22              Reading
# 2  Goodman   90.0   20              Playing
# 3     Hank    NaN   24  Collecting Minerals

# %%
Inner_Join = Marks.merge(Age, on = 'name', how = 'inner')
Inner_Join
# Out:
#       name  marks  age    Hobby
# 0   Walter     70   21  Cooking
# 1     Saul     80   22  Reading
# 2  Goodman     90   20  Playing

# %%
Outer_Join = Marks.merge(Age, on = 'name', how = 'outer')
Outer_Join
# Out:
#       name  marks   age                Hobby
# 0   Walter   70.0  21.0              Cooking
# 1    White   75.0   NaN                  NaN
# 2     Saul   80.0  22.0              Reading
# 3  Goodman   90.0  20.0              Playing
# 4     Hank    NaN  24.0  Collecting Minerals

# %% [markdown]
# # concat()

# %%
Marks1 = pd.DataFrame({'name' : ['Walter','White','Saul','Goodman'],
    'marks' : [70,75,80,90]})
Marks2 = pd.DataFrame({'name' : ['Hank','Pinkman','Mike','Fring'],
    'marks' : [88,72,75,90]})

# %%
Marks1
# Out:
#       name  marks
# 0   Walter     70
# 1    White     75
# 2     Saul     80
# 3  Goodman     90

# %%
Marks2
# Out:
#       name  marks
# 0     Hank     88
# 1  Pinkman     72
# 2     Mike     75
# 3    Fring     90

# %%
a=pd.concat([Marks1,Marks2], axis=0)
a
# Out:
#       name  marks
# 0   Walter     70
# 1    White     75
# 2     Saul     80
# 3  Goodman     90
# 0     Hank     88
# 1  Pinkman     72
# 2     Mike     75
# 3    Fring     90

# %% [markdown]
# # reset_index()

# %%
a.reset_index(drop = True)
# Out:
#       name  marks
# 0   Walter     70
# 1    White     75
# 2     Saul     80
# 3  Goodman     90
# 4     Hank     88
# 5  Pinkman     72
# 6     Mike     75
# 7    Fring     90
